# %% [markdown]
# <a href="https://colab.research.google.com/github/wangdedi1997/Disentanglement-Beta-FactorVAE/blob/master/SPIB_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SPIB Demo 2021
# This notebook aims to serve as a simple introduction to the state predictive information bottleneck method of [Wang and Tiwary 2021](https://aip.scitation.org/doi/abs/10.1063/5.0038198). The code is implemented using Pytorch.

# %% [markdown]
# ![Fig_alg.png](data:image/png;base64,...)

# %% [markdown]
# ![Fig_FW_example.png](data:image/png;base64,...)

# %%
# %matplotlib notebook
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import time

plt.rcParams['figure.figsize'] = [25, 20]
np.random.seed(42)

# %%
large = 54; med = 36; small = 24
l_width = 3; m_width = 1.5; s_width = 0.7
params = {'axes.titlesize': large,
          'legend.fontsize': large,
          'legend.title_fontsize':large,
          'figure.figsize': (16, 10),
          'axes.labelsize': large,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large,
          'lines.linewidth': l_width,
          'lines.markersize': 10,
          'axes.linewidth': l_width,
          'xtick.major.size': 8,
          'ytick.major.size': 8,
          'xtick.minor.size': 4,
          'ytick.minor.size': 4,
          'xtick.major.width': m_width,
          'ytick.major.width': m_width,
          'xtick.minor.width': s_width,
          'ytick.minor.width': s_width,
          'grid.linewidth': m_width}
plt.rcParams.update(params)

# %% [markdown]
# ## Data Preparation
# The trajectory data can be generated from the molecular dynamics simulation or experiements. Here, we use a sample trajectory generated from Langevin dynamics simulation of a four-well analytical potential.

# %%
# Load trajectory data
traj_data = np.load("examples/Four_Well_beta3_gamma4_traj_data.npy")

# %% [markdown]
# ### Visualization of the trajectory

# %%
fig, ax = plt.subplots(figsize=(12,10))

t = np.arange(traj_data.shape[0])
ax.plot(t[::100],traj_data[::100,0],'x',label='x')
ax.plot(t[::100],traj_data[::100,1],'o',fillstyle='none',label='y')
ax.set_xlabel('time step')
ax.legend(fontsize=36,bbox_to_anchor=(0.99, 0.7))

# %%
# The four-well analytical potential along x
def potential_fn_FW(x):
    A=0.6
    a=80
    B=0.2
    b=80
    C=0.5
    c=40
    return 2*(x**8+A*np.exp(-a*x**2)+B*np.exp(-b*(x-0.5)**2)+C*np.exp(-c*(x+0.5)**2))+(x**2-1)**2

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig, ax = plt.subplots(1,2,figsize=(18,8))

beta=3
lw=8

x=np.arange(-1,1,0.01)
v=potential_fn_FW(x)
ax[0].plot(x,v,color='k',lw=lw)
ax[0].axvline(x=0,color='b',linestyle='--',lw=lw)
ax[0].axvline(x=-0.5,color='b',linestyle='--',lw=lw)
ax[0].axvline(x=0.5,color='b',linestyle='--',lw=lw)
ax[0].text(-0.75, 1.8, 'A', horizontalalignment='center',fontsize=54)
ax[0].text(-0.25, 1.8, 'B', horizontalalignment='center', fontsize=54)
ax[0].text(0.25, 1.8, 'C', horizontalalignment='center',fontsize=54)
ax[0].text(0.75, 1.8, 'D', horizontalalignment='center', fontsize=54)
ax[0].set_xlabel("x")
ax[0].set_ylabel("Potential")

ax[0].text(-0.2, 1.2, '(a)', horizontalalignment='center',
             transform=ax[0].transAxes,fontsize=54, va='top')

FW_counts,FW_xbins,FW_ybins,images = plt.hist2d(traj_data[:,0],traj_data[:,1],bins=100)
FW_counts[FW_counts==0]=FW_counts[FW_counts!=0].min()
FW_G=-np.log(FW_counts)/beta
FW_G=FW_G-np.nanmin(FW_G)

h0=ax[1].contourf(FW_G.transpose(),levels=5,extent=[FW_xbins[0],FW_xbins[-1],FW_ybins[0],FW_ybins[-1]],cmap='jet')
divider = make_axes_locatable(ax[1])
cax = divider.append_axes("top", "5%", pad="3%")
tickz = np.arange(0,FW_G.max(),1)
cb1 = fig.colorbar(h0, cax=cax, orientation="horizontal",ticks=tickz)
cb1.set_label('Free Energy',fontsize=48)
cax.xaxis.set_ticks_position("top")
cax.xaxis.set_label_position("top")
ax[1].set_xlabel("x")
ax[1].set_ylabel('y')


ax[1].text(-0.2, 1.3, '(b)', horizontalalignment='center',
             transform=ax[1].transAxes,fontsize=54, va='top')

plt.tight_layout(pad=0.4, w_pad=5, h_pad=3.0)

# %% [markdown]
# ### Generation of initial state labels

# %%
# discretize the system along x to 10 states as initial state labels
index=0

x_max=traj_data[:,index].max()+0.01
x_min=traj_data[:,index].min()-0.01

state_num=10
eps=1e-3

x_det=(x_max-x_min+2*eps)/state_num

init_label=np.zeros((traj_data.shape[0],state_num))

x_list=np.array([(x_min-eps+n*x_det) for n in range(state_num+1)])

for j in range(state_num):
    indices=(traj_data[:,index]>x_list[j])&(traj_data[:,index]<=x_list[j+1])
    init_label[indices,j]=1

np.save('examples/Four_Well_beta3_gamma4_init_label10.npy',init_label)

# %%
# plot the initial state labels for four well potential system
import matplotlib
from matplotlib import colors as c
data=traj_data
labels=init_label

fig0, ax0 = plt.subplots(figsize=(9,6))
hist=ax0.hist2d(data[:,0],data[:,1],bins=100)

state_num=labels.shape[1]
state_labels=np.arange(state_num)

x_max=np.max(data[:,0])
x_min=np.min(data[:,0])

eps=1e-3

x_det=(x_max-x_min+2*eps)/state_num

x_list=np.array([(x_min-eps+n*x_det) for n in range(state_num+1)])

hist_state=np.zeros([state_num]+list(hist[0].shape))

for i in range(state_num):
    hist_state[i]=ax0.hist2d(data[:,0],data[:,1],bins=[hist[1],hist[2]],weights=labels[:,i])[0]
    
init_label_map=np.argmax(hist_state,axis=0).astype(float)
init_label_map[hist[0]==0]=np.nan
plt.close(fig0)

# %%
fig, ax = plt.subplots(figsize=(9,6))

fmt = matplotlib.ticker.FuncFormatter(lambda x, pos: state_labels[x])
tickz = np.arange(0,len(state_labels))

cMap = c.ListedColormap(plt.cm.tab20.colors[0:10])
im=ax.pcolormesh(hist[1], hist[2], init_label_map.T, cmap=cMap, vmin=-0.5, vmax=len(state_labels)-0.5)
cb1 = fig.colorbar(im,ax=ax,format=fmt, ticks=tickz)

for i in range(state_num):
    ax.text((x_list[i]+x_list[i+1])/2,0,state_labels[i],horizontalalignment='center',verticalalignment='center',fontsize=32)
    
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Model
# We provide two ways to run SPIB: test_model.py and test_model_advanced.py. Here, we will only discuss the use of test_model.py. But for advanced analyses, we will strongly recommend to use test_model_advanced.py as it provides more features to help you to control the training process and tune the hyper-parameters.

# %% [markdown]
# ## Training

# %%
# %run test_model.py -dt 50 -d 1 -encoder_type Nonlinear -bs 512 -threshold 0.01 -patience 2 -refinements 8 -lr 0.001 -b 0.01 -seed 0 -label examples/Four_Well_beta3_gamma4_init_label10.npy -traj examples/Four_Well_beta3_gamma4_traj_data.npy
# Out:
# Iteration 500:	Time 2.005146 s
# Loss (train) 1.011449	KL loss (train): 2.238273
# Reconstruction loss (train) 0.989066
# Loss (test) 1.096539	KL loss (test): 2.298395
# Reconstruction loss (test) 1.073555
# tensor([0.0000, 0.2379, 0.0000, 0.0477, 0.0000, 0.0000, 0.1356, 0.0000, 0.5788,
#         0.0000])
# State population change=0.259978
# Epoch: 1
#
# Iteration 1000:	Time 4.244885 s
# Loss (train) 1.019712	KL loss (train): 2.115034
# Reconstruction loss (train) 0.998562
# Loss (test) 0.967001	KL loss (test): 2.085638
# Reconstruction loss (test) 0.946144
# tensor([0.0000, 0.2279, 0.0000, 0.0579, 0.0000, 0.0000, 0.1550, 0.0000, 0.5593,
#         0.0000])
# State population change=0.031010
# Epoch: 2
#
# Iteration 1500:	Time 6.502622 s
# Loss (train) 0.921418	KL loss (train): 2.002204
# Reconstruction loss (train) 0.901396
# Loss (test) 0.965281	KL loss (test): 2.206697
# Reconstruction loss (test) 0.943214
# tensor([0.0000, 0.2276, 0.0000, 0.0581, 0.0000, 0.0000, 0.1615, 0.0000, 0.5528,
#         0.0000])
# State population change=0.009241
# Epoch: 3
#
# Iteration 2000:	Time 8.868172 s
# Loss (train) 1.081617	KL loss (train): 1.994864
# Reconstruction loss (train) 1.061668
# Loss (test) 0.924426	KL loss (test): 2.035758
# Reconstruction loss (test) 0.904068
# tensor([0.0000, 0.2272, 0.0000, 0.0586, 0.0000, 0.0000, 0.1604, 0.0000, 0.5539,
#         0.0000])
# State population change=0.001708
# Epoch: 4
#
# Iteration 2500:	Time 11.048916 s
# Loss (train) 0.938154	KL loss (train): 2.069126
# Reconstruction loss (train) 0.917463
# Loss (test) 0.945261	KL loss (test): 1.981799
# Reconstruction loss (test) 0.925443
# tensor([0.0000, 0.2275, 0.0000, 0.0582, 0.0000, 0.0000, 0.1572, 0.0000, 0.5570,
#         0.0000])
# State population change=0.004501
# Update 1
#
# Epoch: 0
#
# Iteration 3000:	Time 13.614225 s
# Loss (train) 0.235139	KL loss (train): 2.277506
# Reconstruction loss (train) 0.212364
# Loss (test) 0.205868	KL loss (test): 2.289423
# Reconstruction loss (test) 0.182974
# tensor([0.0000, 0.2275, 0.0000, 0.0580, 0.0000, 0.0000, 0.1551, 0.0000, 0.5593,
#         0.0000])
# State population change=0.003112
# Epoch: 1
#
# Iteration 3500:	Time 15.844605 s
# Loss (train) 0.255854	KL loss (train): 2.125474
# Reconstruction loss (train) 0.234599
# Loss (test) 0.267309	KL loss (test): 2.133720
# Reconstruction loss (test) 0.245972
# tensor([0.0000, 0.2277, 0.0000, 0.0581, 0.0000, 0.0000, 0.1619, 0.0000, 0.5523,
#         0.0000])
# State population change=0.009811
# Epoch: 2
#
# Iteration 4000:	Time 18.085978 s
# Loss (train) 0.262119	KL loss (train): 1.964853
# Reconstruction loss (train) 0.242471
# Loss (test) 0.250787	KL loss (test): 2.225088
# Reconstruction loss (test) 0.228537
# tensor([0.0000, 0.2277, 0.0000, 0.0581, 0.0000, 0.0000, 0.1645, 0.0000, 0.5497,
#         0.0000])
# State population change=0.003628
# Update 2
#
# Epoch: 0
#
# Iteration 4500:	Time 20.681509 s
# Loss (train) 0.243460	KL loss (train): 2.195770
# Reconstruction loss (train) 0.221502
# Loss (test) 0.249154	KL loss (test): 2.026096
# Reconstruction loss (test) 0.228893
# tensor([0.0000, 0.2271, 0.0000, 0.0586, 0.0000, 0.0000, 0.1642, 0.0000, 0.5501,
#         0.0000])
# State population change=0.000945
# Epoch: 1
#
# Iteration 5000:	Time 23.043774 s
# Loss (train) 0.216281	KL loss (train): 1.869481
# Reconstruction loss (train) 0.197586
# Loss (test) 0.281110	KL loss (test): 2.032172
# Reconstruction loss (test) 0.260788
# tensor([0.0000, 0.2270, 0.0000, 0.0587, 0.0000, 0.0000, 0.1598, 0.0000, 0.5545,
#         0.0000])
# State population change=0.006259
# Epoch: 2
#
# Iteration 5500:	Time 25.253145 s
# Loss (train) 0.206560	KL loss (train): 2.020746
# Reconstruction loss (train) 0.186353
# Loss (test) 0.242931	KL loss (test): 1.814492
# Reconstruction loss (test) 0.224786
# tensor([0.0000, 0.2268, 0.0000, 0.0588, 0.0000, 0.0000, 0.1635, 0.0000, 0.5509,
#         0.0000])
# State population change=0.005259
# Update 3
#
# Epoch: 0
#
# Iteration 6000:	Time 27.884297 s
# Loss (train) 0.235457	KL loss (train): 1.921234
# Reconstruction loss (train) 0.216244
# Loss (test) 0.250088	KL loss (test): 1.942450
# Reconstruction loss (test) 0.230664
# tensor([0.0000, 0.2267, 0.0000, 0.0589, 0.0000, 0.0000, 0.1664, 0.0000, 0.5479,
#         0.0000])
# State population change=0.004134
# Epoch: 1
#
# Iteration 6500:	Time 30.094284 s
# Loss (train) 0.254466	KL loss (train): 2.059739
# Reconstruction loss (train) 0.233869
# Loss (test) 0.281022	KL loss (test): 1.985762
# Reconstruction loss (test) 0.261164
# tensor([0.0000, 0.2268, 0.0000, 0.0589, 0.0000, 0.0000, 0.1643, 0.0000, 0.5500,
#         0.0000])
# State population change=0.003014
# Epoch: 2
#
# Iteration 7000:	Time 32.420160 s
# Loss (train) 0.279854	KL loss (train): 2.134818
# Reconstruction loss (train) 0.258506
# Loss (test) 0.269937	KL loss (test): 2.110256
# Reconstruction loss (test) 0.248834
# tensor([0.0000, 0.2264, 0.0000, 0.0592, 0.0000, 0.0000, 0.1615, 0.0000, 0.5529,
#         0.0000])
# State population change=0.004080
# Update 4
#
# Epoch: 0
#
# Iteration 7500:	Time 34.895186 s
# Loss (train) 0.249751	KL loss (train): 2.094559
# Reconstruction loss (train) 0.228805
# Loss (test) 0.257743	KL loss (test): 1.756341
# Reconstruction loss (test) 0.240180
# tensor([0.0000, 0.2269, 0.0000, 0.0589, 0.0000, 0.0000, 0.1618, 0.0000, 0.5525,
#         0.0000])
# State population change=0.000776
# Epoch: 1
#
# Iteration 8000:	Time 37.060510 s
# Loss (train) 0.267202	KL loss (train): 1.886928
# Reconstruction loss (train) 0.248333
# Loss (test) 0.280454	KL loss (test): 1.902549
# Reconstruction loss (test) 0.261429
# tensor([0.0000, 0.2264, 0.0000, 0.0593, 0.0000, 0.0000, 0.1619, 0.0000, 0.5524,
#         0.0000])
# State population change=0.000702
# Epoch: 2
#
# Iteration 8500:	Time 39.338630 s
# Loss (train) 0.296982	KL loss (train): 1.968023
# Reconstruction loss (train) 0.277302
# Loss (test) 0.216326	KL loss (test): 1.893329
# Reconstruction loss (test) 0.197393
# tensor([0.0000, 0.2271, 0.0000, 0.0586, 0.0000, 0.0000, 0.1616, 0.0000, 0.5527,
#         0.0000])
# State population change=0.001154
# Update 5
#
# Epoch: 0
#
# Iteration 9000:	Time 41.945632 s
# Loss (train) 0.254997	KL loss (train): 1.913880
# Reconstruction loss (train) 0.235859
# Loss (test) 0.257106	KL loss (test): 2.057557
# Reconstruction loss (test) 0.236531
# Iteration 9500:	Time 43.771601 s
# Loss (train) 0.267387	KL loss (train): 1.889595
# Reconstruction loss (train) 0.248491
# Loss (test) 0.272449	KL loss (test): 1.829703
# Reconstruction loss (test) 0.254152
# tensor([0.0000, 0.2269, 0.0000, 0.0588, 0.0000, 0.0000, 0.1683, 0.0000, 0.5460,
#         0.0000])
# State population change=0.009435
# Epoch: 1
#
# Iteration 10000:	Time 46.135697 s
# Loss (train) 0.260625	KL loss (train): 1.885311
# Reconstruction loss (train) 0.241772
# Loss (test) 0.240779	KL loss (test): 1.961737
# Reconstruction loss (test) 0.221162
# tensor([0.0000, 0.2268, 0.0000, 0.0589, 0.0000, 0.0000, 0.1634, 0.0000, 0.5509,
#         0.0000])
# State population change=0.006890
# Epoch: 2
#
# Iteration 10500:	Time 48.411509 s
# Loss (train) 0.269471	KL loss (train): 1.928015
# Reconstruction loss (train) 0.250191
# Loss (test) 0.238171	KL loss (test): 1.908427
# Reconstruction loss (test) 0.219087
# tensor([0.0000, 0.2268, 0.0000, 0.0588, 0.0000, 0.0000, 0.1603, 0.0000, 0.5541,
#         0.0000])
# State population change=0.004488
# Update 6
#
# Epoch: 0
#
# Iteration 11000:	Time 50.922713 s
# Loss (train) 0.266797	KL loss (train): 1.852914
# Reconstruction loss (train) 0.248268
# Loss (test) 0.226144	KL loss (test): 1.943350
# Reconstruction loss (test) 0.206711
# tensor([0.0000, 0.2268, 0.0000, 0.0589, 0.0000, 0.0000, 0.1607, 0.0000, 0.5536,
#         0.0000])
# State population change=0.000632
# Epoch: 1
#
# Iteration 11500:	Time 53.241966 s
# Loss (train) 0.269993	KL loss (train): 1.916251
# Reconstruction loss (train) 0.250831
# Loss (test) 0.218814	KL loss (test): 1.925619
# Reconstruction loss (test) 0.199558
# tensor([0.0000, 0.2272, 0.0000, 0.0585, 0.0000, 0.0000, 0.1659, 0.0000, 0.5484,
#         0.0000])
# State population change=0.007378
# Epoch: 2
#
# Iteration 12000:	Time 55.466494 s
# Loss (train) 0.274045	KL loss (train): 1.881805
# Reconstruction loss (train) 0.255227
# Loss (test) 0.252589	KL loss (test): 1.815921
# Reconstruction loss (test) 0.234430
# tensor([0.0000, 0.2266, 0.0000, 0.0591, 0.0000, 0.0000, 0.1618, 0.0000, 0.5526,
#         0.0000])
# State population change=0.005891
# Update 7
#
# Epoch: 0
#
# Iteration 12500:	Time 58.270672 s
# Loss (train) 0.277511	KL loss (train): 1.858163
# Reconstruction loss (train) 0.258929
# Loss (test) 0.282685	KL loss (test): 2.013535
# Reconstruction loss (test) 0.262550
# tensor([0.0000, 0.2266, 0.0000, 0.0591, 0.0000, 0.0000, 0.1610, 0.0000, 0.5533,
#         0.0000])
# State population change=0.001104
# Epoch: 1
#
# Iteration 13000:	Time 60.432673 s
# Loss (train) 0.250969	KL loss (train): 1.872308
# Reconstruction loss (train) 0.232246
# Loss (test) 0.277779	KL loss (test): 1.805689
# Reconstruction loss (test) 0.259722
# tensor([0.0000, 0.2266, 0.0000, 0.0590, 0.0000, 0.0000, 0.1604, 0.0000, 0.5540,
#         0.0000])
# State population change=0.000927
# Epoch: 2
#
# Iteration 13500:	Time 62.633312 s
# Loss (train) 0.251921	KL loss (train): 2.033269
# Reconstruction loss (train) 0.231589
# Loss (test) 0.231530	KL loss (test): 1.825714
# Reconstruction loss (test) 0.213273
# tensor([0.0000, 0.2262, 0.0000, 0.0594, 0.0000, 0.0000, 0.1618, 0.0000, 0.5526,
#         0.0000])
# State population change=0.002075
# Update 8
#
# Epoch: 0
#
# Iteration 14000:	Time 65.323742 s
# Loss (train) 0.297641	KL loss (train): 1.813372
# Reconstruction loss (train) 0.279507
# Loss (test) 0.226723	KL loss (test): 1.947094
# Reconstruction loss (test) 0.207252
# tensor([0.0000, 0.2265, 0.0000, 0.0592, 0.0000, 0.0000, 0.1602, 0.0000, 0.5540,
#         0.0000])
# State population change=0.002177
# Epoch: 1
#
# Iteration 14500:	Time 67.589904 s
# Loss (train) 0.204770	KL loss (train): 1.976890
# Reconstruction loss (train) 0.185001
# Loss (test) 0.268156	KL loss (test): 2.019112
# Reconstruction loss (test) 0.247965
# tensor([0.0000, 0.2269, 0.0000, 0.0588, 0.0000, 0.0000, 0.1598, 0.0000, 0.5544,
#         0.0000])
# State population change=0.000793
# Epoch: 2
#
# Iteration 15000:	Time 70.020316 s
# Loss (train) 0.263799	KL loss (train): 1.856565
# Reconstruction loss (train) 0.245233
# Loss (test) 0.294078	KL loss (test): 1.937682
# Reconstruction loss (test) 0.274701
# tensor([0.0000, 0.2262, 0.0000, 0.0595, 0.0000, 0.0000, 0.1605, 0.0000, 0.5537,
#         0.0000])
# State population change=0.001346
# Total training time: 71.582766
# Final: 0
# Loss (train) 0.253254	KL loss (train): 1.878831
# Reconstruction loss (train) 0.234466
# Loss (test) 0.251319	KL loss (train): 1.865809
# Reconstruction loss (test) 0.232661
# dt: 50	 Beta: 0.010000	 Learning_rate: 0.001000

# %% [markdown]
# ## Result Analysis

# %%
prefix='SPIB/Unweighted_d=1_t=50_b=0.0100_learn=0.001000'
repeat='0'

# %%
# load the results
# the deterministic part of RC leanred by SPIB (the mean of output gaussian distrition of the encoder)
traj_mean_rep=np.load(prefix+"_traj0_mean_representation"+repeat+".npy")
# the final state labels leanred by SPIB
traj_labels=np.load(prefix+"_traj0_labels"+repeat+".npy")

# %%
# plot the learned state labels for four well potential system
import matplotlib
from matplotlib import colors as c
data=traj_data
labels=traj_labels
hist=plt.hist2d(data[:,0],data[:,1],bins=100)

state_num=labels.shape[1]
state_labels=np.arange(state_num)

hist_state=np.zeros([state_num]+list(hist[0].shape))

for i in range(state_num):
    hist_state[i]=plt.hist2d(data[:,0],data[:,1],bins=[hist[1],hist[2]],weights=labels[:,i])[0]
    
label_map50=np.argmax(hist_state,axis=0).astype(float)
label_map50[hist[0]==0]=np.nan

plt.close()

# %%
fig, ax = plt.subplots(figsize=(9,6))

fmt = matplotlib.ticker.FuncFormatter(lambda x, pos: state_labels[x])
tickz = np.arange(0,len(state_labels))

cMap = c.ListedColormap(plt.cm.tab20.colors[0:10])
im=ax.pcolormesh(hist[1], hist[2], label_map50.T, cmap=cMap, vmin=-0.5, vmax=len(state_labels)-0.5)
cb1 = fig.colorbar(im,ax=ax,format=fmt, ticks=tickz)

ax.text(-0.75,0,'1',horizontalalignment='center',verticalalignment='center',fontsize=64)
ax.text(0.75,0,'8',horizontalalignment='center',verticalalignment='center',fontsize=64)
ax.text(-0.25,0,'3',horizontalalignment='center',verticalalignment='center',fontsize=64)
ax.text(0.25,0,'6',horizontalalignment='center',verticalalignment='center',fontsize=64)

plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
# plot the learned RC for four well potential system
data=traj_data

hist=plt.hist2d(data[:,0],data[:,1],bins=100)
hist_RC=plt.hist2d(data[:,0],data[:,1],bins=[hist[1],hist[2]],weights=traj_mean_rep[:,0])
plt.close()

# %%
fig, ax = plt.subplots(figsize=(15,10))

RC=np.divide(hist_RC[0],hist[0])

im=ax.contourf(RC.T, extent=[hist_RC[1][0],hist_RC[1][-1],hist_RC[2][0],hist_RC[2][-1]],levels=10,
                    cmap=plt.cm.jet)
cb1 = fig.colorbar(im,ax=ax)
cb1.set_label('RC')

plt.xlabel("x")
plt.ylabel("y")
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
